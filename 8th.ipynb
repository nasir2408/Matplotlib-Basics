# %%
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
from datetime import datetime, timedelta
import pandas as pd
import numpy as np

plt.xkcd()

# %%
#d = [datetime(2019, 5, 24), datetime(2019, 5, 25), datetime(2019, 5, 26), datetime(2019, 5, 27), datetime(2019, 5, 28), datetime(2019, 5, 29), datetime(2019, 5, 30)]
#y = [0, 1, 3, 4, 6, 5, 7]

#plt.plot_date(d, y, linestyle='solid')
#plt.gcf().autofmt_xdate() # get current fig = gcf

#date_format = mpl_dates.DateFormatter('%b, %d, %Y')
#plt.gca().xaxis.set_major_formatter(date_format) # get current axes = gca

data = pd.read_csv('data3.csv')

data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

pd = data['Date']
pc = data['Close']

plt.plot_date(pd, pc, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()
#plt.savefig('ts83.png')

plt.show()
